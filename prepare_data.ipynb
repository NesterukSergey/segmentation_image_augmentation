# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
from utils.show import show

# %%
test_img_path = './data/Plant_Phenotyping_Datasets/Plant/Tobacco/tobacco_plant061_rgb.png'
test_mask_path = './data/Plant_Phenotyping_Datasets/Plant/Tobacco/tobacco_plant061_label.png'

# %%
test_img = plt.imread(test_img_path)
test_mask = plt.imread(test_mask_path)

# %%
show(test_mask)

# %%
test_img.shape
# Out:
# (2048, 2448, 3)

# %%
binary_mask = (test_mask > 0).max(axis=2).astype(int) * 255

# %%
binary_mask.shape
# Out:
# (2048, 2448)

# %%
show([test_img, binary_mask])

# %%
plt.imsave('img.png', test_img)
plt.imsave('mask.png', binary_mask, cmap='gray', vmin=0, vmax=255)
